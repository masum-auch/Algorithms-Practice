# %% [markdown]
# <a href="https://colab.research.google.com/github/masum-auch/Algorithms-Practice/blob/main/supervised/SLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Algorithm | Practices | Visulization | Python

# %%
#import pandas/numpy/seaborn/matplotlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import row data
df= pd.read_csv('/content/nasdaq100.csv', sep= ';')

# %%
df.head()
# Out:
#        Date  Starting (USD)  Ending (USD)
# 0  01.01.24           16800         16500
# 1  01.12.23           15900         16100
# 2  01.11.23           15800         15300
# 3  01.10.23           16100         16200
# 4  01.09.23           16300         15700

# %%
print(df.isnull().sum()[df.isnull().sum()> 0])
# Out:
# Series([], dtype: int64)

# %%
dup= print(df.duplicated())
dup
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#     Starting (USD)  Ending (USD)
# 0            16800         16500
# 1            15900         16100
# 2            15800         15300
# 3            16100         16200
# 4            16300         15700
# 5            16800         16400
# 6            15900         16200
# 7            15800         15500
# 8            16150         16100
# 9            16300         15800
# 10           16200         16200

# %%
#df.drop('Date', axis=1)
# df = df.drop(columns = ['Date'])

# %%
df.head()
# Out:
#    Starting (USD)  Ending (USD)
# 0           16800         16500
# 1           15900         16100
# 2           15800         15300
# 3           16100         16200
# 4           16300         15700

# %%
plt.scatter(data=df, x= 'Starting (USD)' , y= 'Ending (USD)')
plt.xlabel('Starting (USD)')
plt.ylabel('Ending (USD)')
plt.title('NASDAQ100 Stock Prices')
# Out:
# Text(0.5, 1.0, 'NASDAQ100 Stock Prices')

# %%
x = df.drop('Ending (USD)', axis=1)
y = df[['Ending (USD)']]

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
x.mean()
# Out:
# Starting (USD)    16195.833333
# dtype: float64

# %%
y.mean()
# Out:
# Ending (USD)    15975.0
# dtype: float64

# %%
plt.scatter(x.mean() , y.mean(), color='red')
plt.scatter(df['Starting (USD)'] , df['Ending (USD)'])
plt.xlabel('Starting (USD)')
plt.ylabel('Ending (USD)')
plt.title('NASDAQ100 Stock Prices')
# Out:
# Text(0.5, 1.0, 'NASDAQ100 Stock Prices')

# %%
reg.fit(x, y) #train the ml model
# Out:
# LinearRegression()

# %%
m =reg.coef_
m
# Out:
# array([[0.65258293]])

# %%
c= reg.intercept_
c
# Out:
# array([5405.87555702])

# %%
#y = mx + c
y= m*16700 + c
print(y)
# Out:
# [[16304.0105628]]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# reg.predict([[16700]])

# %%
df['predicted_y']= reg.predict(x)
df.head()
# Out:
#    Starting (USD)  Ending (USD)   predicted_y
# 0           16800         16500  16369.268856
# 1           15900         16100  15781.944215
# 2           15800         15300  15716.685922
# 3           16100         16200  15912.460802
# 4           16300         15700  16042.977389

# %%
plt.plot(x, df['predicted_y'])
# plt.scatter(x.mean(), y.mean(), color='red')
plt.scatter(df['Starting (USD)'], df['Ending (USD)'])
plt.xlabel('Starting (USD)')
plt.ylabel('Ending (USD)')
plt.title('NASDAQ100 Stock Prices')
# Out:
# Text(0.5, 1.0, 'NASDAQ100 Stock Prices')
